# %% [markdown]
# # Знакомство с машинным обучением

# %% [markdown]
# ## Описание задачи и загрузка данных

# %% [markdown]
# В этом задании вам нужно обучить линейную регрессию для предсказания стоимости домов в Калифорнии.

# %% [markdown]
# Загружаем необходимые библиотеки.

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# Фиксируем `random_state` для воспроизводимости случайных значений.

# %%
RANDOM_STATE = 42

# %% [markdown]
# Загрузим данные и сформируем из них матрицу объект-признак `X` и вектор `y`, содержащий целевую переменную.

# %%
Data = fetch_california_housing(as_frame=True)

X = Data['data']
y = Data['target']

# %% [markdown]
# Посмотрим первые пять записей набора данных.

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %% [markdown]
# ## Задание 1

# %% [markdown]
#  Сколько строк и столбцов в матрице `X`?

# %%
X.shape
# Out:
# (20640, 8)

# %%
X.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# Посмотрим на зависимость стоимости домов (целевой переменной `y`) от признака `MedInc` (`Median Income`).
# Для этого можно нарисовать диаграмму рассеяния.

# %%
plt.scatter(X['MedInc'], y)
plt.xlabel('Median Income')
plt.ylabel('House Price')
# Out:
# Text(0, 0.5, 'House Price')

# %% [markdown]
# По диаграмме видно, что чем больше `Median Income`, тем больше `House Price`, то есть видна прямая зависимость целевой переменной от признака `MedInc`.

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Постройте диаграмму рассеяния, отображающую зависимость целевой переменной от признака `Latitude`.
# Какая это зависимость?

# %%
plt.scatter(X['Latitude'], y)
plt.xlabel('Latitude')
plt.ylabel('House price')
# Out:
# Text(0, 0.5, 'House price')

# %% [markdown]
# Ещё немного поисследуем данные. Полноценный разведочный анализ в рамках этого задания, конечно, не провести, но какие-то инструменты мы потрогаем.
#
# Давайте построим тепловую карту корреляций.

# %%
corr = X.corr()
sb.heatmap(corr, cmap="Blues", annot=True);

# %% [markdown]
# По этой матрице корреляций видно, что два наиболее зависимых признака - это `AveRooms` и `AveBedrms`.
#
# Но интереснее посмотреть, какой признак имеет наибольшую корреляцию с целевой переменной!

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Добавьте к матрице `X` столбец `y` и постройте матрицу корреляций.
# Какой признак имеет наибольшую по модулю корреляцию с таргетом?
# После выполнения задания удалите добавленный столбец `y` из матрицы `X`.

# %%
X.insert(0,"Price", y)
corr = X.corr()
sb.heatmap(corr, cmap="YlOrRd", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Разбейте данные на тренировочную и тестовую часть (в тест отправьте 25% данных).

# %%
from sklearn.model_selection import train_test_split

y = X.pop('Price')

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.25, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kaban\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 y = X.pop('Price')
#       5 Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.25, shuffle=True)
#       6 print(type(Xtrain))
#
# File c:\Users\kaban\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5819, in DataFrame.pop(self, item)
#    5778 def pop(self, item: Hashable) -> Series:
#    5779     """
#    5780     Return item and drop from frame. Raise KeyError if not found.
#    5781
#    (...)
#    5817     3  monkey        NaN
#    5818     """
# -> 5819     return super().pop(item=item)
#
# File c:\Users\kaban\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:947, in NDFrame.pop(self, item)
#     946 def pop(self, item: Hashable) -> Series | Any:
# --> 947     result = self[item]
#     948     del self[item]
#     950     return result
#
# File c:\Users\kaban\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\kaban\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Price'

# %% [markdown]
# ##Задание 4

# %% [markdown]
# Сколько объектов попали в тест?

# %%
print(Xtest.shape)
Xtrain.shape
# Out:
# 41280
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Обучите линейную регрессию с параметрами по умолчанию на тренировочных данных и сделайте предсказание на тестовых данных.

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(Xtrain, ytrain)
pred = lr.predict(Xtest)

# %%
round(lr.score(Xtest, ytest),1)
# Out:
# 0.6

# %% [markdown]
# ## Задание 5

# %% [markdown]
# Вычислите значение метрики *MSE* на тестовых данных.
# Ответ округлите до десятых.

# %%
from sklearn.metrics import mean_squared_error

# Функция round() принимает несколько аргументов на вход: первое - это само число, второе - кол-во знаков после запятой
err = mean_squared_error(y_pred=pred, y_true=ytest)

print(err)
# Out:
# 0.5352996010445088
